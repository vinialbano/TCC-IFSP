# %% [markdown]
# # Clustering com BERTimbau e K-Means
#
# Neste notebook, utilizaremos o modelo `BERTimbau` para extrair embeddings de textos e, em seguida, utilizaremos o algoritmo K-Means para agrupá-los. O BERTimbau é uma variação do BERT pré-treinada especialmente para o português.
#
# ## 1. Importando as bibliotecas

# %%
# Instalando dependências
# %pip install transformers
# %pip install torch torchvision
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.11/site-packages (4.33.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.11/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.11/site-packages (0.15.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from torchvision) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from transformers import BertTokenizer, BertModel
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Carregando os dados

# %%
# Carregando os dados
df = pd.read_csv("./data/Leis de Sorocaba (Clean).csv")

# Preenchendo os valores nulos com uma string vazia:
df['summary'] = df['summary'].fillna('')

# Remover termos irrelevantes:
remove_phrases = ['dispor sobre', 'dar outro providência', 'dar outro providencia']
remove_phrases_regex = '|'.join(remove_phrases)
df['summary'] = df['summary'].str.replace(remove_phrases_regex, ' ', regex=True).str.strip()

# %% [markdown]
# ## 3. Preparando o modelo BERTimbau
#
# Carregaremos o tokenizador e o modelo BERTimbau para extrair os embeddings.

# %%
tokenizer = BertTokenizer.from_pretrained('neuralmind/bert-base-portuguese-cased')
model = BertModel.from_pretrained('neuralmind/bert-base-portuguese-cased')
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %% [markdown]
# ## 4. Função para Extração de Embeddings
#
# Vamos definir uma função que irá nos ajudar a extrair embeddings do BERTimbau para nossos textos.

# %%
def extract_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    # Utilizaremos o CLS token (primeira posição) como a representação do texto
    return outputs['last_hidden_state'][0][0].numpy()

# Exemplo
sample_text = "Texto exemplo para testar a função."
print(extract_embedding(sample_text))
# Out:
# [ 1.48464024e-01 -1.24193549e-01  2.46683955e-01  3.58867645e-01
#   3.53321046e-01  4.13656056e-01  1.23279579e-01 -2.49590874e-01
#   5.38282216e-01  1.63538441e-01 -5.46482325e-01  1.04740240e-01
#   2.72754937e-01 -1.19842999e-02  2.33041361e-01 -3.14009696e-01]

# %% [markdown]
# ## 5. Extração dos Embeddings
#
# Vamos processar nossos dados e extrair os embeddings para cada texto.

# %%
df['embedding'] = df['summary'].apply(extract_embedding)

# %% [markdown]
# ## 5. Agrupamento com K-Means
#
# Agora, utilizaremos o algoritmo K-Means para agrupar os embeddings.

# %%
X = np.array(df['embedding'].tolist())
kmeans = KMeans(n_clusters=11, n_init=10)  # Aqui, estamos supondo 11 clusters, mas você pode escolher outro número
df['cluster'] = kmeans.fit_predict(X)

# %% [markdown]
# ## 6. Análise dos Clusters
#
# Finalmente, vamos analisar os clusters formados.

# %%
# Calculando o número de documentos por cluster
df['cluster'].value_counts().plot(kind='bar', title='Número de documentos por cluster')
plt.xlabel('Cluster')
plt.ylabel('Número de documentos')
plt.show()

# %%
# Exibindo algumas amostras de textos por cluster
num_samples = 11  # você pode ajustar esse número conforme desejar

for cluster in df['cluster'].unique():
    print(f"\nCluster {cluster}:\n")
    samples = df[df['cluster'] == cluster]['summary'].sample(num_samples)
    for idx, sample in enumerate(samples, 1):
        print(f"{idx}. {sample}\n")
# Out:
# Cluster 3:
#
# 1. atitude respeito bandeira hino
#
# 2. código obra município
#
# 3. denominação Alberto grosso pem-so Nº 34 de este cidade
#
# 4. denominação fausto Ferreira Telles próprio público cidade
#
# 5. denominação trovador candini via público cidade
#
# 6. denominação gentil Francisco gebaile pontilhão cidade
#
# 7. denominação fausto Ferreira Telles praça público cidade
#
# 8. regulamento mercado municipal
#
# 9. denominação plácido Rodrigues Miranda praça público cidade
#
# 10. denominação professora darlene devasto próprio público cidade
#
# 11. alteração descrição rua Pedro Moreira césar
#
#
# Cluster 4:
#
# 1. denominação laércio Rocha via público cidade
#
# 2. denominação José alípio Soares Filho via público cidade
#
# 3. denominação José Abel Buckart via público cidade
#
# 4. denominação drjurgen ulderup via público cidade
#
# 5. denominação Francisca Paula Jesus Izabel via público cidade
#
# 6. denominação Sueli Martins Madureira via público cidade
#
# 7. denominação Antônia Simão Rodrigues via público cidade
#
# 8. denominação Antonieta Marques Ferreira via público cidade
#
# 9. denominação venceslau Ferreira Campos via público cidade
#
# 10. denominação Maria aparecer césar Rodrigues via público cidade
#
# 11. denominação drwaldemar oliveira Ramos via público cidade
#
#
# Cluster 2:
#
# 1. alterar lei Nº 9895 TOKEN_DATA reorganizar estrutura administrativo serviço autônomo água esgoto saae
#
# 2. criação ginásio municipal bairro Felipe
#
# 3. instituir dia atenção fissurado lábio-palatal comemorar anualmente 17 setembro
#
# 4. celebração convênio Secretaria Estado negócio educação
#
# 5. alteração lei municipal Nº 10657 TOKEN_DATA criar campanha permanente incentivo doação medula óssea dia municipal Medula
#
# 6. inclusão atividade extracurricular ensino atividade Educação trânsito escola municipal
#
# 7. doação terreno govêrno estado Paulo construção centro difusão cultural
#
# 8. instituir dia municipal coletor varredor lixo celebrar anualmente dia 16 maio homenagem realizar casa lei
#
# 9. dotação suplementar irmandade Santa casa Misericórdia Sorocaba
#
# 10. concessão subvenção anual estabelecimento ensino superior município
#
# 11. alteração denominação cargo coordenador ensino superior coordenador ação cultural comunitário
#
#
# Cluster 1:
#
# 1. modificar redação lei Nº 8746 TOKEN_DATA acrescentar dia municipal escritor sorocabano
#
# 2. acrescentar dispositivo junto lei Nº 8426 TOKEN_DATA alterar lei Nº 8941 TOKEN_DATA
#
# 3. dar novo redação artigo 1 3 lei Nº 3226 TOKEN_DATA
#
# 4. acrescentar inciso artigo 1 lei 2378 TOKEN_DATA
#
# 5. alterar redação artigo 7 12 lei Nº 10051 TOKEN_DATA
#
# 6. alterar dispositivo lei Nº 9414 TOKEN_DATA
#
# 7. prorrogação prazo apresentação declaração prever lei Nº 355 TOKEN_DATA
#
# 8. alterar redação artigo 1 decreto Nº 2178 TOKEN_DATA denominar avenida Fernando Stecca via público município
#
# 9. alterar redação artigo 14 29 34 lei Nº 4599 TOKEN_DATA alterar lei Nº 8119 TOKEN_DATA estabelecer quadro plano carreira quadro magistério público Municipal Sorocaba
#
# 10. revogação lei Nº 9783 TOKEN_DATA
#
# 11. acrescentar alínea j inciso i artigo 15 lei Nº 4168 TOKEN_DATA
#
#
# Cluster 5:
#
# 1. proibição uso fumo veículo transporte coletivo
#
# 2. criação divisão planejamento controle pessoal junto secretaria educação cultura seção cargo mencionar
#
# 3. penalidade aplicável indústria poluír curso água município
#
# 4. alteração legislação referente tributo municipal
#
# 5. estabelecer disposição relativo organização sociedade civil interesse público
#
# 6. regulamente horário comercial festa natalino
#
# 7. criação divisão apoio portador deficiência dad seção cargo mencionar
#
# 8. obrigatoriedade órgão administração público municipal disponibilizar endereço eletrônico relação pessoa desaparecir
#
# 9. estabelecer condição depósito dinheiro público estabelecimento decrédito séde município
#
# 10. forma pagamento débito inscritos dívida ativo contribuinte município
#
# 11. conceder isenção tributo construção popular
#
#
# Cluster 8:
#
# 1. declarar utilidade público Associação profissional usuário processamento dado Sorocaba região
#
# 2. declarar utilidade público Associação voluntário Sorocaba
#
# 3. declarar utilidade público Monte Real futebol clube
#
# 4. declarar faca sorocaba bem imaterial cultural município Sorocaba
#
# 5. doar terreno fábrica nacional implemento Howard s /
#
# 6. instituir dia violeiro
#
# 7. declarar utilidade público centro apoio pesquisa integração desenvolvimento capide
#
# 8. instituição município Sorocaba dia colônia israelita
#
# 9. declarar utilidade público vila hortência futebol clube
#
# 10. declarar utilidade público Associação quadrangular ação social aqua
#
# 11. declarar utilidade público Associação advogado Sorocaba
#
#
# Cluster 6:
#
# 1. instituir regime jurídico servidor admitir serviço caráter temporário contratar função natureza técnico especializar termo artigo 37 item ix constituição federal
#
# 2. autorizar prefeitura Municipal Sorocaba celebrar convênio associação formação reeducação luar novo implantação custeio casa acolhimento transitório tipo infanto-juvenil casa aprendiz
#
# 3. identificação empresa contratar município sorocaba cumpridora lei decreto federal referente obrigatoriedade preenchimento cota aprendiz deficiente
#
# 4. autorizar prefeitura municipal celebrar convênio Fundação Centro brasileiro infância adolescência fcbia
#
# 5. autorizar município celebrar convênio associação bom pastor visar continuidade ampliação execução projeto primeiro chance
#
# 6. planta genérico valor terreno construção município Sorocaba exercício 1994   Câmara municipal decretar promulgo seguinte Lei artigo 1 planta genérico valor município Sorocaba determinar valor Metro quadrado terreno construção localizar sede bairro acordo anexo de este lei par1 logradouro trecho logradouro constar planta genérico valor valor Metro quadrado terreno fixar órgão competente Secretaria edificação característica artigo 2 valor constante rol referência cadastral anexo lei corresponder àquele vigente TOKEN_DATA devidamente corrigir TOKEN_DATA índice obter prioritariamente através levantamento técnico efetuar secretária edificação urbanismo falta variação unidade Fiscal município Sorocaba u.f.m.s ocorrir períodoparágrafo único valor unitário ficar lei somente revisto ocorrer fator significativo importar valorização imóveisnão ocorrer tal fator poder executivo poder atualizar valor monetário acordo método estabelecer caput de este artigo artigo 3 valor Metro quadrado terreno construção constante de este lei atualizar cálculo valor venal imóvel tributar imposto sobre propriedade predial territorial urbano após corrigir termo artigo 2parágrafo único efeito recolhimento imposto sobre transmissão bem imóvel inter vivo valor Metro quadrado terreno construção constante de este lei poder atualizar mensalmente partir TOKEN_DATA decreto poder executivo limite total variação mercado imobiliário demonstrar através levantamento técnico efetuar Secretaria edificação urbanismo falta variação unidade Fiscal município Sorocaba u.f.m.s ocorrer período artigo 4 lei entrar vigor data publicação revogar todo disposição contrário palácio tropeiro TOKEN_DATA 340 fundação Sorocaba Paulo Francisco Mendes prefeito municipal
#
# 7. instituir termos artigo 182 § 4 constituição federal instrumento cumprimento função social propriedade urbano município Sorocaba através iptu progressivo
#
# 8. autorizar prefeitura municipal contratar empréstimo caixa econômico Estado
#
# 9. autorizar prefeitura municipal celebrar convênio cooperação técnico-educacional universidade estadual Paulista Júlio Mesquita filho estabelecimento curso superior engenharia controle automação outro bem
#
# 10. autorizar Executivo municipal celebrar convênio governo estado Paulo regulamentar participação município projeto Banco povo destinar concessão crédito Micro empreendimento setor formal informal instalar município
#
# 11. autorizar poder executivo contratar operação crédito junto banco Brasil S.ae   correlato
#
#
# Cluster 9:
#
# 1. reajuste salarial funcionalismo público Municipal
#
# 2. criação cargo gestor administrativo estabelecimento saúde alterar súmula atribuição função gratificar coordenador técnico unidade urgência emergêncio especialidade
#
# 3. diretriz realização censo servidor público municipal ativo
#
# 4. redução jornada trabalho ocupante cargo psicólogo i
#
# 5. concessão bolsas estudo escola particular educação especial
#
# 6. reajuste vencimento
#
# 7. criar ampliar alterar cargo quadro permanente administração direto fundacional
#
# 8. instituir regime especial dedicação cargo fiscal comércio prefeitura municipal
#
# 9. enquadramento funcional
#
# 10. concessão gratificação funcionário forma estabelecer
#
# 11. conceder gratificação ocupante cargo diretor tesouro
#
#
# Cluster 10:
#
# 1. desafetar bem uso comum autorizar doação fazenda estado Paulo
#
# 2. declaração utilidade público terreno desapropriação
#
# 3. doação imóvel fazenda estado Paulo construção escola bairro wanel ville iv
#
# 4. desafetação bem imóvel uso comum concedir direito real uso associação morador vila Colorau
#
# 5. instituição área especial interesse social ael fim inclusão programa urbanização regularização fundiário
#
# 6. autorização desafetação alienação imóvel remanescente obra público proprietário lindeiro
#
# 7. desapropriação área terreno construção logradouro publico vila dia Lopes
#
# 8. desafetar bem imóvel uso comum concedir direito real uso comunidade kolping Francisco Assis
#
# 9. aquisição terreno doação puro simples
#
# 10. autorizar venda imóvel remanescente desapropriação proprietário lindeiro
#
# 11. doação terreno
#
#
# Cluster 0:
#
# 1. denominação Alameda buriti via público cidade
#
# 2. determinar poste dar sustentação rede aéreo distribuição energia elétrico retirar frente garagem colocar divisa lote terreno casa área urbano
#
# 3. denominação André vargas Rodrigues prolongamento via público
#
# 4. denominação Alameda bacuri via público cidade
#
# 5. denominação prolongamento via público
#
# 6. denominação via público
#
# 7. denominação rua Antônio roque Rodrigues prolongamento via público cidade
#
# 8. denominação raymundo frutuoso Silva prolongamento rua 02 jardim conrar
#
# 9. denominação prolongamento via público
#
# 10. denominação prolongamento via público
#
# 11. denominação via público
#
#
# Cluster 7:
#
# 1. abertura crédito especial
#
# 2. abertura crédito
#
# 3. abertura crédito especial
#
# 4. autorização executivo contrair empréstimo valor cr$ TOKEN_VALOR
#
# 5. autorizar realização operação crédito
#
# 6. abertura crédito especial
#
# 7. abertura crédito especial cr$ TOKEN_VALOR
#
# 8. abertura crédito especial suplementar
#
# 9. proibição depósito dinheiro público estabelecimento crédito particular capital inferior cr$ TOKEN_VALOR
#
# 10. autorização abertura crédito especial
#
# 11. autorizar cancelamento débito fiscal importância cr$ TOKEN_VALOR

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_representative_docs_for_cluster(cluster_id, df, n_docs=5):
    # Filtrar embeddings pelo cluster
    cluster_embeddings = np.array(df[df['cluster'] == cluster_id]['embedding'].tolist())
    
    # Calcular o vetor médio do cluster
    centroid = cluster_embeddings.mean(axis=0)
    
    # Calcular a similaridade entre o centroide e todos os documentos no cluster
    similarities = cosine_similarity(cluster_embeddings, centroid.reshape(1, -1))
    
    # Pegar os n_docs documentos mais similares
    top_docs_indices = similarities.flatten().argsort()[-n_docs:][::-1]
    
    return df[df['cluster'] == cluster_id].iloc[top_docs_indices]

def get_top_terms_for_cluster(cluster_id, df, n_docs=5, n_terms=10):
    representative_docs = get_representative_docs_for_cluster(cluster_id, df, n_docs)
    
    # Tokenização e contagem de termos dos documentos representativos
    all_terms = []
    for doc in representative_docs['summary']:
        all_terms.extend(doc.split())  # supondo que os documentos já estejam tokenizados
    
    # Usando Counter para pegar os termos mais comuns
    from collections import Counter
    counter = Counter(all_terms)
    
    return [item[0] for item in counter.most_common(n_terms)]

# %%
# Exemplo de uso:
cluster_id = 4  # Exemplo de cluster
print(get_top_terms_for_cluster(cluster_id, df, n_docs=150, n_terms=10))
# Out:
# ['via', 'público', 'cidade', 'denominação', 'José', 'João', 'Antonio', 'Oliveira', 'Carlos', 'Antônio']
